# %%
# %sql

select * from chocolate_sales_kaggle.target.calendar_bronze;

# %%
# %sql

describe table calander_bronze;

# %%
# %sql 
describe table chocolate_sales_kaggle.target.customer_bronze;
select * from chocolate_sales_kaggle.target.customer_bronze;

# %%
# %sql
select * from chocolate_sales_kaggle.target.customer_bronze where age >= 100;

# %%
# %sql 
describe table chocolate_sales_kaggle.target.product_bronze;
select * from chocolate_sales_kaggle.target.product_bronze;

# %%
# %sql
describe table chocolate_sales_kaggle.target.sales_bronze;
select * from chocolate_sales_kaggle.target.sales_bronze;

describe table chocolate_sales_kaggle.target.store_bronze;
select * from chocolate_sales_kaggle.target.store_bronze;

# %%
# %sql
describe table chocolate_sales_kaggle.target.sales_bronze;
select * from chocolate_sales_kaggle.target.sales_bronze;
