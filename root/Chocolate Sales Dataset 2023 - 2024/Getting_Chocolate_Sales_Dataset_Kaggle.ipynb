# %%
# %pip install kaggle

# %%
download_path = "/Volumes/chocolate_sales_kaggle/default/chocolate_sales_dataset_kaggle/source_kaggle"
dbutils.fs.mkdirs(download_path)

# %%
import os 
os.environ['KAGGLE_USERNAME'] = "roshands51"
os.environ['KAGGLE_KEY'] = "d51a1677c4465c733af8be427138b66e"

# %%
# !kaggle datasets list

# %%
# !kaggle datasets download -d ssssws/chocolate-sales-dataset-2023-2024 -p "{download_path}" --unzip

# %%
# !kaggle datasets download \
-d ssssws/chocolate-sales-dataset-2023-2024 \
-p /Volumes/chocolate_sales_kaggle/default/chocolate_sales_dataset_kaggle/source_kaggle \
--unzip

# %%
display(dbutils.fs.ls("/Volumes/chocolate_sales_kaggle/default/chocolate_sales_dataset_kaggle/source_kaggle"))

# %%
df_calender = spark.read.csv("dbfs:/Volumes/chocolate_sales_kaggle/default/chocolate_sales_dataset_kaggle/source_kaggle/calendar.csv", header=True, inferSchema=True)

display(df_calender)

# %%
df_customer = spark.read.csv("dbfs:/Volumes/chocolate_sales_kaggle/default/chocolate_sales_dataset_kaggle/source_kaggle/customers.csv",header=True,inferSchema=True)
display(df_customer)

df_products = spark.read.csv("dbfs:/Volumes/chocolate_sales_kaggle/default/chocolate_sales_dataset_kaggle/source_kaggle/products.csv",header=True,inferSchema=True)
display(df_products)

df_sales = spark.read.csv("dbfs:/Volumes/chocolate_sales_kaggle/default/chocolate_sales_dataset_kaggle/source_kaggle/sales.csv",header=True,inferSchema=True)
display(df_sales)

df_store = spark.read.csv("dbfs:/Volumes/chocolate_sales_kaggle/default/chocolate_sales_dataset_kaggle/source_kaggle/stores.csv",header=True,inferSchema=True)
display(df_store)

# %%
df_list = [df_calender, df_customer, df_products, df_sales, df_store]
for i in range(len(df_list)):
    print(df_list[i])
    df_list[i].printSchema()
